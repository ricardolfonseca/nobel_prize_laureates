# %% [markdown]
# The Nobel Prize has been among the most prestigious international awards since 1901. Each year, awards are bestowed in chemistry, literature, physics, physiology or medicine, economics, and peace. In addition to the honor, prestige, and substantial prize money, the recipient also gets a gold medal with an image of Alfred Nobel (1833 - 1896), who established the prize.
#
# ![](Nobel_Prize.png)
#
# The Nobel Foundation has made a dataset available of all prize winners from the outset of the awards from 1901 to 2023. The dataset used in this project is from the Nobel Prize API and is available in the `nobel.csv` file in the `data` folder.
#
# In this project, you'll get a chance to explore and answer several questions related to this prizewinning data. And we encourage you then to explore further questions that you're interested in!

# %% [markdown]
# #### 1. What is the most commonly awarded gender and birth country?

# %%
import pandas as pd
from functions import *

if __name__ == '__main__':

    # Read CSV
    nobel_df = pd.read_csv('data/nobel.csv')

    # Analyze 'sex' column
    top_gender = get_max_value_and_plot(nobel_df, 'sex')
    print(f"Top gender(s): {', '.join(top_gender)}")

    # Analyze 'birth_country' column
    top_country = get_max_value_and_plot(nobel_df, 'birth_country')
    print(f"Top country/countries: {', '.join(top_country)}")

# %% [markdown]
# #### 2. Which decade had the highest ratio of US-born Nobel Prize winners to total winners in all categories?

# %%
import pandas as pd
from functions import *

if __name__ == '__main__':
    
    # Load Nobel Prize data
    nobel_df = pd.read_csv('data/nobel.csv')

    # Calculate the ratio of US-born winners by decade
    nobel_grouped = calculate_us_ratio_by_decade(nobel_df)

    # Get the decade with the highest US-born winners ratio
    max_decade_usa = get_decade_with_highest_us_ratio(nobel_grouped)

    # Print the result
    print(f'The decade with the highest ratio of US-born winners is: {max_decade_usa}.')

    # Plot the US-born winners ratio over decades
    plot_us_ratio_over_decades(nobel_grouped)
# Out:
# The decade with the highest ratio of US-born winners is: 2000.

# %% [markdown]
# #### 3. What is the decade and category with highest proportion of female laureates? Save the answer as a dictionary.

# %%
import pandas as pd
from functions import *

if __name__ == '__main__':
    
    # Read CSV
    nobel_df = pd.read_csv('data/nobel.csv')

    # Calculate the decade and category with the highest proportion of female laureates
    max_female_dict = get_max_female_decade_category(nobel_df)
    print("Decade and category with highest proportion of female laureates:")
    print(max_female_dict)
    
    # Plot the number of Nobel laureates by gender over decades
    plot_gender_over_decades(nobel_df)

# %% [markdown]
# #### 4. Who was the first woman to receive a Nobel Prize, and in what category?
# ##### Display all categories won by female laureates and how the first compares to the others

# %%
import pandas as pd
from functions import *

if __name__ == '__main__':
    
    # Read CSV
    nobel_df = pd.read_csv('data/nobel.csv')

    # Get the first female laureate
    first_woman_name, first_woman_category, first_woman_year = get_first_female_laureate(nobel_df)

    # Print the results
    print(f"The first woman to receive a Nobel Prize was {first_woman_name} in the category of {first_woman_category} in {first_woman_year}.")

    # Visualize categories won by female laureates, highlighting the first laureate's category
    plot_categories_of_female_laureates(nobel_df, first_woman_category)
# Out:
# The first woman to receive a Nobel Prize was Marie Curie, née Sklodowska in the category of Physics in 1903.

# %% [markdown]
# #### 5. Which individuals or organizations have won more than one Nobel Prize throughout the years?
# ##### Create a visual to display the information

# %%
import pandas as pd
from functions import *

if __name__ == '__main__':
    
    # Read CSV
    nobel_df = pd.read_csv('data/nobel.csv')    

    # Get repeat winners
    repeat_winners = get_repeat_winners(nobel_df)

    if repeat_winners.empty:
        print("There are no individuals or organizations with more than one Nobel Prize.")
    else:
        # Extract the names into a list
        repeat_list = repeat_winners['full_name'].tolist()

        # Print the result
        print("Individuals or organizations with more than one Nobel Prize:")
        for index, row in repeat_winners.iterrows():
            print(f"{row['full_name']}: {row['prize_count']} prizes")

        # Plot repeat winners
        plot_repeat_winners(repeat_winners)
# Out:
# Individuals or organizations with more than one Nobel Prize:
# Comité international de la Croix Rouge (International Committee of the Red Cross): 3 prizes
# Frederick Sanger: 2 prizes
# John Bardeen: 2 prizes
# Linus Carl Pauling: 2 prizes
# Marie Curie, née Sklodowska: 2 prizes
# Office of the United Nations High Commissioner for Refugees (UNHCR): 2 prizes
